# %% [markdown]
# # <font color='blue'> Scrapping NBA - Basketball data </font>
#
# #### Website: [NBA Stats](http://stats.nba.com)
#
#
#
# #### Tool: [Basket Strategies in Shiny](https://mariazm.shinyapps.io/basketstrategies/)

# %%
import json

# %% [markdown]
# ### JavaScript and JSON to Python dictionaries (.js)

# %%
### Downloading the JAVASCRIPT file
### http://stats.nba.com/js/data/ptsd/stats_ptsd.js

out_pathname = "scrap_docs/stats_ptsd.js"
    data = jf.read()
    
# JavaScript Variable
target_variable = "stats_ptsd = "
index_variable = data.find(target_variable)
print ( "\nThe variable required is located at the character-index number {0} \n".format(index_variable) )

# We should notice here that the data is structured in the folllowing way: 
# Douible quotes for prinicipal dictionaries: Generated, seasons_count, teams_count, players_count and data

string_for_json = data[ index_variable+len(target_variable): -1]    # -1 to get rid of the semicolon  ;
data_json = json.loads(string_for_json)

print ("Principal keys: {}\n".format(data_json.keys()))
print ("Secondary data-keys: {}\n".format(data_json['data'].keys()))
# Out:
# The variable required is located at the character-index number 4
#
# Principal keys: [u'generated', u'players_count', u'data', u'teams_count', u'seasons_count']
#
# Secondary data-keys: [u'seasons', u'players', u'teams']

# %% [markdown]
# ### JSON to Python dictionaries (.json)
#
#
# <table class="image">
# <caption text-align="center">This is how the data looks today!! </caption>
# <tr><td><img src="Capture.PNG" style="max-width:100%; width: 50%; max-width: none; text: 'hello'" ></td></tr>
# </table>

# %%
### Downloading the JSON file
### http://stats.nba.com/schedule/summerleague/#!?PD=N
### http://data.nba.com/data/10s/v2015/json/mobile_teams/utah/2017/scores/14_todays_scores.json

out_pathname = "scrap_docs/14_full_schedule.json"
with open(out_pathname,'r') as jf:  
    data = json.load(jf)
    
print data['lscd'][0]['mscd']['mon'] + "\n"
print "Options:", data['lscd'][0]['mscd']['g'][1].keys(), "\n"

print "Example:\n"
print data['lscd'][0]['mscd']['g'][0]['v']  #Visit
print data['lscd'][0]['mscd']['g'][0]['h']  # Host
print "\n"
# Out:
# July
#
# Options: [u'bd', u'h', u'ac', u'ptsls', u'seq', u'gcode', u'is', u'v', u'vtm', u'an', u'stt', u'as', u'gid', u'gdte', u'st', u'ppdst', u'gdtutc', u'etm', u'htm', u'utctm', u'seri']
#
# Example:
#
# {u'tn': u'Hornets', u're': u'1-0', u's': u'74', u'tid': 1610612766, u'tc': u'Charlotte', u'ta': u'CHA'}
# {u'tn': u'Heat', u're': u'0-1', u's': u'67', u'tid': 1610612748, u'tc': u'Miami', u'ta': u'MIA'}

# %% [markdown]
# ### JSON format with Elastic Search engine
#
# This is an example of how to work with elastic search in Python. You should first install the ElasticSearch Python-package and set-up your elkasticsearch server. In other words, this means (in a local environment) that while using the following Python commands, I need to have a terminal/shell open (inside the elasticsearch/bin folder) in my computer with 'ElasticSearch' exec-file running [(details here).](https://www.elastic.co/downloads/elasticsearch)
#
# This engine is a distributed and multitenant full-text search for JSON free-sructured documents. It has an HTTP web interface (we need the server/host) and it has been used by Facebook, Mozilla, Soundcloud, among others. It was developed in Java and now released public available by Apache.

# %%
from elasticsearch import Elasticsearch, helpers
import sys, os

es = Elasticsearch()

def load_json(filename):
    if filename.endswith('.json'):
        with open(filename,'r') as open_file:
            yield json.load(open_file)

helpers.bulk(es, load_json("scrap_docs/14_full_schedule.json"), index='index_basket', doc_type='games_scores')
# Out:
# (1, [])

# %%
## Search for Miami - team

#result = es.search(index='index_basket', doc_type='games_scores', body={"query": {"match": {"_id": "AV1RYls2qXy3PnP3U4gf"}} } )
result= es.get(index='index_basket', doc_type='games_scores', id= "AV1RacXtqXy3PnP3U4go")
                   
result['_source']
# Out:
# {u'lscd': [{u'mscd': {u'g': [{u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-01T11:00:00',
#       u'gcode': u'20170701/CHAMIA',
#       u'gdte': u'2017-07-01',
#       u'gdtutc': u'2017-07-01',
#       u'gid': u'1421700001',
#       u'h': {u're': u'0-1',
#        u's': u'67',
#        u'ta': u'MIA',
#        u'tc': u'Miami',
#        u'tid': 1610612748,
#        u'tn': u'Heat'},
#       u'htm': u'2017-07-01T11:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Okaro',
#          u'ln': u'White',
#          u'pid': u'1627855',
#          u'ta': u'MIA',
#          u'tc': u'Miami',
#          u'tid': 1610612748,
#          u'tn': u'Heat',
#          u'val': u'20'}]},
#       u'seq': 1,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'15:00',
#       u'v': {u're': u'1-0',
#        u's': u'74',
#        u'ta': u'CHA',
#        u'tc': u'Charlotte',
#        u'tid': 1610612766,
#        u'tn': u'Hornets'},
#       u'vtm': u'2017-07-01T11:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-01T13:00:00',
#       u'gcode': u'20170701/ORLIND',
#       u'gdte': u'2017-07-01',
#       u'gdtutc': u'2017-07-01',
#       u'gid': u'1421700002',
#       u'h': {u're': u'1-0',
#        u's': u'85',
#        u'ta': u'IND',
#        u'tc': u'Indiana',
#        u'tid': 1610612754,
#        u'tn': u'Pacers'},
#       u'htm': u'2017-07-01T13:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Travis',
#          u'ln': u'Leslie',
#          u'pid': u'202727',
#          u'ta': u'IND',
#          u'tc': u'Indiana',
#          u'tid': 1610612754,
#          u'tn': u'Pacers',
#          u'val': u'20'}]},
#       u'seq': 2,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'17:00',
#       u'v': {u're': u'0-1',
#        u's': u'74',
#        u'ta': u'ORL',
#        u'tc': u'Orlando',
#        u'tid': 1610612753,
#        u'tn': u'Magic'},
#       u'vtm': u'2017-07-01T13:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'},
#         {u'disp': u'KTXA',
#          u'lan': u'English',
#          u'scope': u'home',
#          u'seq': 2,
#          u'type': u'tv'},
#         {u'disp': u'MSG',
#          u'lan': u'English',
#          u'scope': u'away',
#          u'seq': 3,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-01T15:00:00',
#       u'gcode': u'20170701/NYKDAL',
#       u'gdte': u'2017-07-01',
#       u'gdtutc': u'2017-07-01',
#       u'gid': u'1421700003',
#       u'h': {u're': u'1-0',
#        u's': u'80',
#        u'ta': u'DAL',
#        u'tc': u'Dallas',
#        u'tid': 1610612742,
#        u'tn': u'Mavericks'},
#       u'htm': u'2017-07-01T15:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Dwight',
#          u'ln': u'Buycks',
#          u'pid': u'202779',
#          u'ta': u'DAL',
#          u'tc': u'Dallas',
#          u'tid': 1610612742,
#          u'tn': u'Mavericks',
#          u'val': u'16'}]},
#       u'seq': 3,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'19:00',
#       u'v': {u're': u'0-1',
#        u's': u'75',
#        u'ta': u'NYK',
#        u'tc': u'New York',
#        u'tid': 1610612752,
#        u'tn': u'Knicks'},
#       u'vtm': u'2017-07-01T15:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-01T17:00:00',
#       u'gcode': u'20170701/OKCDET',
#       u'gdte': u'2017-07-01',
#       u'gdtutc': u'2017-07-01',
#       u'gid': u'1421700004',
#       u'h': {u're': u'0-1',
#        u's': u'91',
#        u'ta': u'DET',
#        u'tc': u'Detroit',
#        u'tid': 1610612765,
#        u'tn': u'Pistons'},
#       u'htm': u'2017-07-01T17:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Vincent',
#          u'ln': u'Hunter',
#          u'pid': u'1626205',
#          u'ta': u'OKC',
#          u'tc': u'Oklahoma City',
#          u'tid': 1610612760,
#          u'tn': u'Thunder',
#          u'val': u'21'},
#         {u'fn': u'Henry',
#          u'ln': u'Ellenson',
#          u'pid': u'1627740',
#          u'ta': u'DET',
#          u'tc': u'Detroit',
#          u'tid': 1610612765,
#          u'tn': u'Pistons',
#          u'val': u'21'}]},
#       u'seq': 4,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'21:00',
#       u'v': {u're': u'1-0',
#        u's': u'92',
#        u'ta': u'OKC',
#        u'tc': u'Oklahoma City',
#        u'tid': 1610612760,
#        u'tn': u'Thunder'},
#       u'vtm': u'2017-07-01T17:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'},
#         {u'disp': u'MSG',
#          u'lan': u'English',
#          u'scope': u'away',
#          u'seq': 2,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-02T13:00:00',
#       u'gcode': u'20170702/NYKDET',
#       u'gdte': u'2017-07-02',
#       u'gdtutc': u'2017-07-02',
#       u'gid': u'1421700005',
#       u'h': {u're': u'1-1',
#        u's': u'103',
#        u'ta': u'DET',
#        u'tc': u'Detroit',
#        u'tid': 1610612765,
#        u'tn': u'Pistons'},
#       u'htm': u'2017-07-02T13:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Chasson',
#          u'ln': u'Randle',
#          u'pid': u'1626184',
#          u'ta': u'NYK',
#          u'tc': u'New York',
#          u'tid': 1610612752,
#          u'tn': u'Knicks',
#          u'val': u'16'}]},
#       u'seq': 1,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'17:00',
#       u'v': {u're': u'0-2',
#        u's': u'78',
#        u'ta': u'NYK',
#        u'tc': u'New York',
#        u'tid': 1610612752,
#        u'tn': u'Knicks'},
#       u'vtm': u'2017-07-02T13:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-02T15:00:00',
#       u'gcode': u'20170702/ORLMIA',
#       u'gdte': u'2017-07-02',
#       u'gdtutc': u'2017-07-02',
#       u'gid': u'1421700006',
#       u'h': {u're': u'0-2',
#        u's': u'68',
#        u'ta': u'MIA',
#        u'tc': u'Miami',
#        u'tid': 1610612748,
#        u'tn': u'Heat'},
#       u'htm': u'2017-07-02T15:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Okaro',
#          u'ln': u'White',
#          u'pid': u'1627855',
#          u'ta': u'MIA',
#          u'tc': u'Miami',
#          u'tid': 1610612748,
#          u'tn': u'Heat',
#          u'val': u'15'},
#         {u'fn': u'Jonathan',
#          u'ln': u'Isaac',
#          u'pid': u'1628371',
#          u'ta': u'ORL',
#          u'tc': u'Orlando',
#          u'tid': 1610612753,
#          u'tn': u'Magic',
#          u'val': u'15'}]},
#       u'seq': 2,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'19:00',
#       u'v': {u're': u'1-1',
#        u's': u'81',
#        u'ta': u'ORL',
#        u'tc': u'Orlando',
#        u'tid': 1610612753,
#        u'tn': u'Magic'},
#       u'vtm': u'2017-07-02T15:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-02T17:00:00',
#       u'gcode': u'20170702/INDCHA',
#       u'gdte': u'2017-07-02',
#       u'gdtutc': u'2017-07-02',
#       u'gid': u'1421700007',
#       u'h': {u're': u'1-1',
#        u's': u'77',
#        u'ta': u'CHA',
#        u'tc': u'Charlotte',
#        u'tid': 1610612766,
#        u'tn': u'Hornets'},
#       u'htm': u'2017-07-02T17:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Travis',
#          u'ln': u'Leslie',
#          u'pid': u'202727',
#          u'ta': u'IND',
#          u'tc': u'Indiana',
#          u'tid': 1610612754,
#          u'tn': u'Pacers',
#          u'val': u'20'}]},
#       u'seq': 3,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'21:00',
#       u'v': {u're': u'2-0',
#        u's': u'84',
#        u'ta': u'IND',
#        u'tc': u'Indiana',
#        u'tid': 1610612754,
#        u'tn': u'Pacers'},
#       u'vtm': u'2017-07-02T17:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'},
#         {u'disp': u'MSG',
#          u'lan': u'English',
#          u'scope': u'away',
#          u'seq': 2,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-03T13:00:00',
#       u'gcode': u'20170703/NYKOKC',
#       u'gdte': u'2017-07-03',
#       u'gdtutc': u'2017-07-03',
#       u'gid': u'1421700008',
#       u'h': {u're': u'2-0',
#        u's': u'99',
#        u'ta': u'OKC',
#        u'tc': u'Oklahoma City',
#        u'tid': 1610612760,
#        u'tn': u'Thunder'},
#       u'htm': u'2017-07-03T13:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Josh',
#          u'ln': u'Huestis',
#          u'pid': u'203962',
#          u'ta': u'OKC',
#          u'tc': u'Oklahoma City',
#          u'tid': 1610612760,
#          u'tn': u'Thunder',
#          u'val': u'26'}]},
#       u'seq': 1,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'17:00',
#       u'v': {u're': u'0-3',
#        u's': u'87',
#        u'ta': u'NYK',
#        u'tc': u'New York',
#        u'tid': 1610612752,
#        u'tn': u'Knicks'},
#       u'vtm': u'2017-07-03T13:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-03T15:00:00',
#       u'gcode': u'20170703/ORLDAL',
#       u'gdte': u'2017-07-03',
#       u'gdtutc': u'2017-07-03',
#       u'gid': u'1421700009',
#       u'h': {u're': u'2-0',
#        u's': u'86',
#        u'ta': u'DAL',
#        u'tc': u'Dallas',
#        u'tid': 1610612742,
#        u'tn': u'Mavericks'},
#       u'htm': u'2017-07-03T15:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Dwight',
#          u'ln': u'Buycks',
#          u'pid': u'202779',
#          u'ta': u'DAL',
#          u'tc': u'Dallas',
#          u'tid': 1610612742,
#          u'tn': u'Mavericks',
#          u'val': u'20'},
#         {u'fn': u'Marcus',
#          u'ln': u'Georges-Hunt',
#          u'pid': u'1627875',
#          u'ta': u'ORL',
#          u'tc': u'Orlando',
#          u'tid': 1610612753,
#          u'tn': u'Magic',
#          u'val': u'20'}]},
#       u'seq': 2,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'19:00',
#       u'v': {u're': u'1-2',
#        u's': u'76',
#        u'ta': u'ORL',
#        u'tc': u'Orlando',
#        u'tid': 1610612753,
#        u'tn': u'Magic'},
#       u'vtm': u'2017-07-03T15:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-03T17:00:00',
#       u'gcode': u'20170703/INDMIA',
#       u'gdte': u'2017-07-03',
#       u'gdtutc': u'2017-07-03',
#       u'gid': u'1421700010',
#       u'h': {u're': u'0-3',
#        u's': u'83',
#        u'ta': u'MIA',
#        u'tc': u'Miami',
#        u'tid': 1610612748,
#        u'tn': u'Heat'},
#       u'htm': u'2017-07-03T17:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Bam',
#          u'ln': u'Adebayo',
#          u'pid': u'1628389',
#          u'ta': u'MIA',
#          u'tc': u'Miami',
#          u'tid': 1610612748,
#          u'tn': u'Heat',
#          u'val': u'29'}]},
#       u'seq': 3,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'21:00',
#       u'v': {u're': u'3-0',
#        u's': u'86',
#        u'ta': u'IND',
#        u'tc': u'Indiana',
#        u'tid': 1610612754,
#        u'tn': u'Pacers'},
#       u'vtm': u'2017-07-03T17:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-04T13:00:00',
#       u'gcode': u'20170704/CHAOKC',
#       u'gdte': u'2017-07-04',
#       u'gdtutc': u'2017-07-04',
#       u'gid': u'1421700011',
#       u'h': {u're': u'2-1',
#        u's': u'81',
#        u'ta': u'OKC',
#        u'tc': u'Oklahoma City',
#        u'tid': 1610612760,
#        u'tn': u'Thunder'},
#       u'htm': u'2017-07-04T13:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Treveon',
#          u'ln': u'Graham',
#          u'pid': u'1626203',
#          u'ta': u'CHA',
#          u'tc': u'Charlotte',
#          u'tid': 1610612766,
#          u'tn': u'Hornets',
#          u'val': u'19'}]},
#       u'seq': 1,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'17:00',
#       u'v': {u're': u'2-1',
#        u's': u'95',
#        u'ta': u'CHA',
#        u'tc': u'Charlotte',
#        u'tid': 1610612766,
#        u'tn': u'Hornets'},
#       u'vtm': u'2017-07-04T13:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-04T15:00:00',
#       u'gcode': u'20170704/INDDAL',
#       u'gdte': u'2017-07-04',
#       u'gdtutc': u'2017-07-04',
#       u'gid': u'1421700012',
#       u'h': {u're': u'3-0',
#        u's': u'94',
#        u'ta': u'DAL',
#        u'tc': u'Dallas',
#        u'tid': 1610612742,
#        u'tn': u'Mavericks'},
#       u'htm': u'2017-07-04T15:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Jameel',
#          u'ln': u'Warney',
#          u'pid': u'1627866',
#          u'ta': u'DAL',
#          u'tc': u'Dallas',
#          u'tid': 1610612742,
#          u'tn': u'Mavericks',
#          u'val': u'17'}]},
#       u'seq': 2,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'19:00',
#       u'v': {u're': u'3-1',
#        u's': u'79',
#        u'ta': u'IND',
#        u'tc': u'Indiana',
#        u'tid': 1610612754,
#        u'tn': u'Pacers'},
#       u'vtm': u'2017-07-04T15:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-04T17:00:00',
#       u'gcode': u'20170704/MIADET',
#       u'gdte': u'2017-07-04',
#       u'gdtutc': u'2017-07-04',
#       u'gid': u'1421700013',
#       u'h': {u're': u'2-1',
#        u's': u'73',
#        u'ta': u'DET',
#        u'tc': u'Detroit',
#        u'tid': 1610612765,
#        u'tn': u'Pistons'},
#       u'htm': u'2017-07-04T17:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Okaro',
#          u'ln': u'White',
#          u'pid': u'1627855',
#          u'ta': u'MIA',
#          u'tc': u'Miami',
#          u'tid': 1610612748,
#          u'tn': u'Heat',
#          u'val': u'29'}]},
#       u'seq': 3,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'21:00',
#       u'v': {u're': u'0-4',
#        u's': u'71',
#        u'ta': u'MIA',
#        u'tc': u'Miami',
#        u'tid': 1610612748,
#        u'tn': u'Heat'},
#       u'vtm': u'2017-07-04T17:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-05T13:00:00',
#       u'gcode': u'20170705/DALOKC',
#       u'gdte': u'2017-07-05',
#       u'gdtutc': u'2017-07-05',
#       u'gid': u'1421700014',
#       u'h': {u're': u'2-2',
#        u's': u'75',
#        u'ta': u'OKC',
#        u'tc': u'Oklahoma City',
#        u'tid': 1610612760,
#        u'tn': u'Thunder'},
#       u'htm': u'2017-07-05T13:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Brandon',
#          u'ln': u'Paul',
#          u'pid': u'203464',
#          u'ta': u'DAL',
#          u'tc': u'Dallas',
#          u'tid': 1610612742,
#          u'tn': u'Mavericks',
#          u'val': u'20'}]},
#       u'seq': 1,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'17:00',
#       u'v': {u're': u'4-0',
#        u's': u'96',
#        u'ta': u'DAL',
#        u'tc': u'Dallas',
#        u'tid': 1610612742,
#        u'tn': u'Mavericks'},
#       u'vtm': u'2017-07-05T13:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-05T15:00:00',
#       u'gcode': u'20170705/CHADET',
#       u'gdte': u'2017-07-05',
#       u'gdtutc': u'2017-07-05',
#       u'gid': u'1421700015',
#       u'h': {u're': u'3-1',
#        u's': u'87',
#        u'ta': u'DET',
#        u'tc': u'Detroit',
#        u'tid': 1610612765,
#        u'tn': u'Pistons'},
#       u'htm': u'2017-07-05T15:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Henry',
#          u'ln': u'Ellenson',
#          u'pid': u'1627740',
#          u'ta': u'DET',
#          u'tc': u'Detroit',
#          u'tid': 1610612765,
#          u'tn': u'Pistons',
#          u'val': u'29'}]},
#       u'seq': 2,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'19:00',
#       u'v': {u're': u'2-2',
#        u's': u'82',
#        u'ta': u'CHA',
#        u'tc': u'Charlotte',
#        u'tid': 1610612766,
#        u'tn': u'Hornets'},
#       u'vtm': u'2017-07-05T15:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'},
#         {u'disp': u'MSG',
#          u'lan': u'English',
#          u'scope': u'home',
#          u'seq': 2,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-05T17:00:00',
#       u'gcode': u'20170705/ORLNYK',
#       u'gdte': u'2017-07-05',
#       u'gdtutc': u'2017-07-05',
#       u'gid': u'1421700016',
#       u'h': {u're': u'0-4',
#        u's': u'73',
#        u'ta': u'NYK',
#        u'tc': u'New York',
#        u'tid': 1610612752,
#        u'tn': u'Knicks'},
#       u'htm': u'2017-07-05T17:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Kalin',
#          u'ln': u'Lucas',
#          u'pid': u'203564',
#          u'ta': u'ORL',
#          u'tc': u'Orlando',
#          u'tid': 1610612753,
#          u'tn': u'Magic',
#          u'val': u'20'}]},
#       u'seq': 3,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'21:00',
#       u'v': {u're': u'2-2',
#        u's': u'84',
#        u'ta': u'ORL',
#        u'tc': u'Orlando',
#        u'tid': 1610612753,
#        u'tn': u'Magic'},
#       u'vtm': u'2017-07-05T17:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'},
#         {u'disp': u'MSG',
#          u'lan': u'English',
#          u'scope': u'away',
#          u'seq': 2,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-06T08:00:00',
#       u'gcode': u'20170706/NYKMIA',
#       u'gdte': u'2017-07-06',
#       u'gdtutc': u'2017-07-06',
#       u'gid': u'1421700017',
#       u'h': {u're': u'0-5',
#        u's': u'72',
#        u'ta': u'MIA',
#        u'tc': u'Miami',
#        u'tid': 1610612748,
#        u'tn': u'Heat'},
#       u'htm': u'2017-07-06T08:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Damyean',
#          u'ln': u'Dotson',
#          u'pid': u'1628422',
#          u'ta': u'NYK',
#          u'tc': u'New York',
#          u'tid': 1610612752,
#          u'tn': u'Knicks',
#          u'val': u'20'}]},
#       u'seq': 1,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'12:00',
#       u'v': {u're': u'1-4',
#        u's': u'91',
#        u'ta': u'NYK',
#        u'tc': u'New York',
#        u'tid': 1610612752,
#        u'tn': u'Knicks'},
#       u'vtm': u'2017-07-06T08:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-06T10:00:00',
#       u'gcode': u'20170706/CHAORL',
#       u'gdte': u'2017-07-06',
#       u'gdtutc': u'2017-07-06',
#       u'gid': u'1421700018',
#       u'h': {u're': u'2-3',
#        u's': u'78',
#        u'ta': u'ORL',
#        u'tc': u'Orlando',
#        u'tid': 1610612753,
#        u'tn': u'Magic'},
#       u'htm': u'2017-07-06T10:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Dwayne',
#          u'ln': u'Bacon',
#          u'pid': u'1628407',
#          u'ta': u'CHA',
#          u'tc': u'Charlotte',
#          u'tid': 1610612766,
#          u'tn': u'Hornets',
#          u'val': u'29'}]},
#       u'seq': 2,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'14:00',
#       u'v': {u're': u'3-2',
#        u's': u'86',
#        u'ta': u'CHA',
#        u'tc': u'Charlotte',
#        u'tid': 1610612766,
#        u'tn': u'Hornets'},
#       u'vtm': u'2017-07-06T10:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-06T12:00:00',
#       u'gcode': u'20170706/OKCIND',
#       u'gdte': u'2017-07-06',
#       u'gdtutc': u'2017-07-06',
#       u'gid': u'1421700019',
#       u'h': {u're': u'4-1',
#        u's': u'89',
#        u'ta': u'IND',
#        u'tc': u'Indiana',
#        u'tid': 1610612754,
#        u'tn': u'Pacers'},
#       u'htm': u'2017-07-06T12:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Semaj',
#          u'ln': u'Christon',
#          u'pid': u'203902',
#          u'ta': u'OKC',
#          u'tc': u'Oklahoma City',
#          u'tid': 1610612760,
#          u'tn': u'Thunder',
#          u'val': u'21'}]},
#       u'seq': 3,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'16:00',
#       u'v': {u're': u'2-3',
#        u's': u'80',
#        u'ta': u'OKC',
#        u'tc': u'Oklahoma City',
#        u'tid': 1610612760,
#        u'tn': u'Thunder'},
#       u'vtm': u'2017-07-06T12:00:00'},
#      {u'ac': u'Orlando',
#       u'an': u'Amway Center',
#       u'as': u'FL',
#       u'bd': {u'b': [{u'disp': u'NBATV',
#          u'lan': u'English',
#          u'scope': u'natl',
#          u'seq': 1,
#          u'type': u'tv'}]},
#       u'etm': u'2017-07-06T14:00:00',
#       u'gcode': u'20170706/DETDAL',
#       u'gdte': u'2017-07-06',
#       u'gdtutc': u'2017-07-06',
#       u'gid': u'1421700020',
#       u'h': {u're': u'5-0',
#        u's': u'83',
#        u'ta': u'DAL',
#        u'tc': u'Dallas',
#        u'tid': 1610612742,
#        u'tn': u'Mavericks'},
#       u'htm': u'2017-07-06T14:00:00',
#       u'is': 1,
#       u'ppdst': u'I',
#       u'ptsls': {u'pl': [{u'fn': u'Dwight',
#          u'ln': u'Buycks',
#          u'pid': u'202779',
#          u'ta': u'DAL',
#          u'tc': u'Dallas',
#          u'tid': 1610612742,
#          u'tn': u'Mavericks',
#          u'val': u'28'}]},
#       u'seq': 4,
#       u'seri': u'',
#       u'st': u'3',
#       u'stt': u'Final',
#       u'utctm': u'18:00',
#       u'v': {u're': u'3-2',
#        u's': u'81',
#        u'ta': u'DET',
#        u'tc': u'Detroit',
#        u'tid': 1610612765,
#        u'tn': u'Pistons'},
#       u'vtm': u'2017-07-06T14:00:00'}],
#     u'mon': u'July'}}]}

# %%
es.indices.delete(index='index_basket', ignore=[400, 404])
# Out:
# {u'acknowledged': True}

# %% [markdown]
# ### JSON from the web  (json response from the web)

# %%
### Using internet protocol to download a JSON

import requests
import pandas as pd

my_url= 'http://stats.nba.com/stats/commonteamroster?LeagueID=00&Season=2013-06&TeamID=1610612737'

# We can get this from Inspect -> Network -> Headers -> Request headers -> User Agent
# It changes if you use IOS or Windows 

headers_nba = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
response = requests.get(my_url, headers = headers_nba)

headers = response.json()['resultSets'][0]['headers']
players = response.json()['resultSets'][0]['rowSet']
players_df = pd.DataFrame(players, columns=headers)

players_df.head(10)
# Out:
#        TeamID SEASON LeagueID           PLAYER NUM POSITION HEIGHT WEIGHT  \
# 0  1610612737   2013       00      Jeff Teague   0        G    6-2    181
# 1  1610612737   2013       00     Lou Williams   3        G    6-1    175
# 2  1610612737   2013       00     Paul Millsap   4        F    6-8    253
# 3  1610612737   2013       00  DeMarre Carroll   5        F    6-8    212
# 4  1610612737   2013       00       Pero Antic   6        C   6-11    260
# 5  1610612737   2013       00     Shelvin Mack   8        G    6-3    207
# 6  1610612737   2013       00     John Jenkins  12        G    6-4    215
# 7  1610612737   2013       00     Gustavo Ayon  14      F-C   6-10    250
# 8  1610612737   2013       00       Al Horford  15      C-F   6-10    250
# 9  1610612737   2013       00  Dennis Schroder  17        G    6-1    168
#
#      BIRTH_DATE   AGE EXP                  SCHOOL  PLAYER_ID
# 0  JUN 10, 1988  26.0   4             Wake Forest     201952
# 1  OCT 27, 1986  27.0   8  South Gwinnett HS (GA)     101150
# 2  FEB 10, 1985  29.0   7          Louisiana Tech     200794
# 3  JUL 27, 1986  27.0   4                Missouri     201960
# 4  JUL 29, 1982  31.0   R               Macedonia     203544
# 5  APR 22, 1990  24.0   2                  Butler     202714
# 6  MAR 06, 1991  23.0   1              Vanderbilt     203098
# 7  APR 01, 1985  29.0   2           Tepic, Mexico     202970
# 8  JUN 03, 1986  28.0   6                 Florida     201143
# 9  SEP 15, 1993  20.0   R                 Germany     203471

# %%
### Video Demo
#<p>
#<video controls src="Attachments/App_Demo.mp4" />
#</p>
